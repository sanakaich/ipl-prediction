# %% [markdown]
# # **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

# %%
matches = pd.read_csv('/content/IPL_Matches_2008_2022.csv')
ball = pd.read_csv('/content/IPL_Ball_by_Ball_2008_2022.csv')

# %% [markdown]
# # **Visualization**

# %%
matches1 = matches

# %%
matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
ball.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
matches.shape
# Out:
# (950, 20)

# %%
ball.shape
# Out:
# (225954, 17)

# %% [markdown]
# # **Preprocessing**

# %% [markdown]
# Finding total runs for each innings in each game

# %%
total_score_df = ball.groupby(['ID','innings'])['total_run'].sum().reset_index()

# %%
total_score_df
# Out:
#            ID  innings  total_run
# 0      335982        1        222
# 1      335982        2         82
# 2      335983        1        240
# 3      335983        2        207
# 4      335984        1        129
# ...       ...      ...        ...
# 1923  1312198        2        193
# 1924  1312199        1        157
# 1925  1312199        2        161
# 1926  1312200        1        130
# 1927  1312200        2        133
#
# [1928 rows x 3 columns]

# %%
total_score_df = total_score_df[total_score_df['innings']==2]

# %%
total_score_df
# Out:
#            ID  innings  total_run
# 1      335982        2         82
# 3      335983        2        207
# 5      335984        2        132
# 7      335985        2        166
# 9      335986        2        112
# ...       ...      ...        ...
# 1919  1304116        2        160
# 1921  1312197        2        191
# 1923  1312198        2        193
# 1925  1312199        2        161
# 1927  1312200        2        133
#
# [948 rows x 3 columns]

# %%
matches=matches.merge(total_score_df[['ID','total_run']],left_on='ID',right_on='ID' )

# %%
matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# 3             Eden Gardens, Kolkata        Gujarat Titans        field  ...
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat  ...
#
#                    WinningTeam    WonBy Margin  method Player_of_Match  \
# 0               Gujarat Titans  Wickets    7.0     NaN       HH Pandya
# 1             Rajasthan Royals  Wickets    7.0     NaN      JC Buttler
# 2  Royal Challengers Bangalore     Runs   14.0     NaN      RM Patidar
# 3               Gujarat Titans  Wickets    7.0     NaN       DA Miller
# 4                 Punjab Kings  Wickets    5.0     NaN   Harpreet Brar
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2 total_run
# 0    Nitin Menon       133
# 1    Nitin Menon       161
# 2       MA Gough       193
# 3      VK Sharma       191
# 4  NA Patwardhan       160
#
# [5 rows x 21 columns]

# %% [markdown]
# Removing unwanted teams

# %%
matches['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Kings XI Punjab',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals'
    'Gujarat Titans'
    'Lucknow Super Giants'
]

# %%
matches['Team1'] = matches['Team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
matches['Team2'] = matches['Team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')
matches['Team1'] = matches['Team1'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
matches['Team2'] = matches['Team2'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
matches['Team1'] = matches['Team1'].str.replace('Kings XI Punjab', 'Punjab Kings')
matches['Team2'] = matches['Team2'].str.replace('Kings XI Punjab', 'Punjab Kings')
matches['Team1'] = matches['Team1'].str.replace('Gujarat Lions', 'Gujarat Titans')
matches['Team2'] = matches['Team2'].str.replace('Gujarat Lions', 'Gujarat Titans')

matches = matches[matches['Team1'].isin(teams)]
matches = matches[matches['Team2'].isin(teams)]

# %%
matches.shape
# Out:
# (605, 21)

# %% [markdown]
# Remove matches with D/L applied

# %%
matches = matches[matches["method"] != "D/L"]

# %%
matches.shape
# Out:
# (596, 21)

# %% [markdown]
# Feature extraction

# %%
matches = matches[['ID','City','WinningTeam','total_run']]

# %%
matches
# Out:
#           ID       City                  WinningTeam  total_run
# 1    1312199  Ahmedabad             Rajasthan Royals        161
# 5    1304115     Mumbai               Mumbai Indians        160
# 6    1304114     Mumbai             Rajasthan Royals        151
# 9    1304111     Mumbai          Sunrisers Hyderabad        190
# 13   1304107       Pune        Kolkata Knight Riders        123
# ..       ...        ...                          ...        ...
# 941   335988  Hyderabad             Delhi Daredevils        143
# 943   335986    Kolkata        Kolkata Knight Riders        112
# 944   335985     Mumbai  Royal Challengers Bangalore        166
# 945   335984      Delhi             Delhi Daredevils        132
# 947   335982  Bangalore        Kolkata Knight Riders         82
#
# [596 rows x 4 columns]

# %%
ball_df=matches.merge(ball,on='ID')

# %%
ball_df.head()
# Out:
#         ID       City       WinningTeam  total_run_x  innings  overs  \
# 0  1312199  Ahmedabad  Rajasthan Royals          161        1      0
# 1  1312199  Ahmedabad  Rajasthan Royals          161        1      0
# 2  1312199  Ahmedabad  Rajasthan Royals          161        1      0
# 3  1312199  Ahmedabad  Rajasthan Royals          161        1      0
# 4  1312199  Ahmedabad  Rajasthan Royals          161        1      0
#
#    ballnumber        batter    bowler   non-striker extra_type  batsman_run  \
# 0           1       V Kohli  TA Boult  F du Plessis        NaN            0
# 1           2       V Kohli  TA Boult  F du Plessis        NaN            1
# 2           3  F du Plessis  TA Boult       V Kohli        NaN            1
# 3           4       V Kohli  TA Boult  F du Plessis        NaN            0
# 4           5       V Kohli  TA Boult  F du Plessis        NaN            0
#
#    extras_run  total_run_y  non_boundary  isWicketDelivery player_out kind  \
# 0           0            0             0                 0        NaN  NaN
# 1           0            1             0                 0        NaN  NaN
# 2           0            1             0                 0        NaN  NaN
# 3           0            0             0                 0        NaN  NaN
# 4           0            0             0                 0        NaN  NaN
#
#   fielders_involved                  BattingTeam
# 0               NaN  Royal Challengers Bangalore
# 1               NaN  Royal Challengers Bangalore
# 2               NaN  Royal Challengers Bangalore
# 3               NaN  Royal Challengers Bangalore
# 4               NaN  Royal Challengers Bangalore

# %% [markdown]
# Only taking the innings 2

# %%
ball_df = ball_df[ball_df['innings']==2]

# %%
ball_df.head()
# Out:
#           ID       City       WinningTeam  total_run_x  innings  overs  \
# 127  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 128  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 129  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 130  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 131  1312199  Ahmedabad  Rajasthan Royals          161        2      0
#
#      ballnumber       batter          bowler non-striker extra_type  \
# 127           1  YBK Jaiswal  Mohammed Siraj  JC Buttler        NaN
# 128           2  YBK Jaiswal  Mohammed Siraj  JC Buttler        NaN
# 129           3  YBK Jaiswal  Mohammed Siraj  JC Buttler        NaN
# 130           4  YBK Jaiswal  Mohammed Siraj  JC Buttler        NaN
# 131           5  YBK Jaiswal  Mohammed Siraj  JC Buttler        NaN
#
#      batsman_run  extras_run  total_run_y  non_boundary  isWicketDelivery  \
# 127            0           0            0             0                 0
# 128            0           0            0             0                 0
# 129            6           0            6             0                 0
# 130            4           0            4             0                 0
# 131            0           0            0             0                 0
#
#     player_out kind fielders_involved       BattingTeam
# 127        NaN  NaN               NaN  Rajasthan Royals
# 128        NaN  NaN               NaN  Rajasthan Royals
# 129        NaN  NaN               NaN  Rajasthan Royals
# 130        NaN  NaN               NaN  Rajasthan Royals
# 131        NaN  NaN               NaN  Rajasthan Royals

# %% [markdown]
# Extracting Current Score

# %%
ball_df['total_run_y'] = pd.to_numeric(ball_df['total_run_y'])
ball_df['current_score'] = ball_df.groupby('ID')['total_run_y'].cumsum()

# %%
ball_df.columns
# Out:
# Index(['ID', 'City', 'WinningTeam', 'total_run_x', 'innings', 'overs',
#        'ballnumber', 'batter', 'bowler', 'non-striker', 'extra_type',
#        'batsman_run', 'extras_run', 'total_run_y', 'non_boundary',
#        'isWicketDelivery', 'player_out', 'kind', 'fielders_involved',
#        'BattingTeam', 'current_score'],
#       dtype='object')

# %% [markdown]
# Extracting Runs Left

# %%
ball_df['runs_left'] = ball_df['total_run_x'] - ball_df['current_score'] + 1

# %%
ball_df.columns
# Out:
# Index(['ID', 'City', 'WinningTeam', 'total_run_x', 'innings', 'overs',
#        'ballnumber', 'batter', 'bowler', 'non-striker', 'extra_type',
#        'batsman_run', 'extras_run', 'total_run_y', 'non_boundary',
#        'isWicketDelivery', 'player_out', 'kind', 'fielders_involved',
#        'BattingTeam', 'current_score', 'runs_left', 'balls_left',
#        'wickets_left', 'crr', 'rrr', 'result', 'BowlingTeam'],
#       dtype='object')

# %% [markdown]
# Extracting Balls Left

# %%
ball_df['balls_left'] =  126 - (ball_df['overs']*6 + ball_df['ballnumber'])

# %% [markdown]
# Extracting Wickets Left

# %%
ball_df['player_out'] = ball_df['player_out'].fillna("0")
ball_df['player_out'] = ball_df['player_out'].apply(lambda x:x if x == "0" else "1")
ball_df['player_out'] = ball_df['player_out'].astype(int)

wickets = ball_df.groupby('ID')['player_out'].cumsum().values
ball_df['wickets_left'] = 10 - wickets

# %%
ball_df.head()
# Out:
#           ID       City       WinningTeam  total_run_x  innings  overs  \
# 127  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 128  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 129  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 130  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 131  1312199  Ahmedabad  Rajasthan Royals          161        2      0
#
#      ballnumber       batter          bowler non-striker  ...  \
# 127           1  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 128           2  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 129           3  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 130           4  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 131           5  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
#
#     fielders_involved       BattingTeam  current_score  runs_left  balls_left  \
# 127               NaN  Rajasthan Royals              0        162         125
# 128               NaN  Rajasthan Royals              0        162         124
# 129               NaN  Rajasthan Royals              6        156         123
# 130               NaN  Rajasthan Royals             10        152         122
# 131               NaN  Rajasthan Royals             10        152         121
#
#      wickets_left   crr       rrr result                  BowlingTeam
# 127             9  -0.0  7.728000      1  Royal Challengers Bangalore
# 128             8  -0.0  7.790323      1  Royal Challengers Bangalore
# 129             7 -12.0  7.560976      1  Royal Challengers Bangalore
# 130             6 -30.0  7.426230      1  Royal Challengers Bangalore
# 131             5 -60.0  7.487603      1  Royal Challengers Bangalore
#
# [5 rows x 28 columns]

# %% [markdown]
# Extracting Current Run Rate

# %%
ball_df['crr'] = ball_df['current_score']*6/(120 - ball_df['balls_left'])

# %% [markdown]
# Extracting Required Run Rate

# %%
ball_df['rrr'] = ball_df['runs_left']*6/ball_df['balls_left']

# %% [markdown]
# Extracting Result

# %%
def result(row):
  return 1  if row['BattingTeam'] == row['WinningTeam'] else 0

# %%
ball_df['result']=ball_df.apply(result,axis=1)

# %%
ball_df.head()
# Out:
#           ID       City       WinningTeam  total_run_x  innings  overs  \
# 127  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 128  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 129  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 130  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 131  1312199  Ahmedabad  Rajasthan Royals          161        2      0
#
#      ballnumber       batter          bowler non-striker  ...  \
# 127           1  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 128           2  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 129           3  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 130           4  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 131           5  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
#
#     fielders_involved       BattingTeam  current_score  runs_left  balls_left  \
# 127               NaN  Rajasthan Royals              0        162         125
# 128               NaN  Rajasthan Royals              0        162         124
# 129               NaN  Rajasthan Royals              6        156         123
# 130               NaN  Rajasthan Royals             10        152         122
# 131               NaN  Rajasthan Royals             10        152         121
#
#      wickets_left   crr       rrr result                  BowlingTeam
# 127             9  -0.0  7.776000      1  Royal Challengers Bangalore
# 128             8  -0.0  7.838710      1  Royal Challengers Bangalore
# 129             7 -12.0  7.609756      1  Royal Challengers Bangalore
# 130             6 -30.0  7.475410      1  Royal Challengers Bangalore
# 131             5 -60.0  7.537190      1  Royal Challengers Bangalore
#
# [5 rows x 28 columns]

# %% [markdown]
# Extracting Bowling Team

# %%
ball_df.columns
# Out:
# Index(['ID', 'City', 'WinningTeam', 'total_run_x', 'innings', 'overs',
#        'ballnumber', 'batter', 'bowler', 'non-striker', 'extra_type',
#        'batsman_run', 'extras_run', 'total_run_y', 'non_boundary',
#        'isWicketDelivery', 'player_out', 'kind', 'fielders_involved',
#        'BattingTeam', 'current_score', 'runs_left', 'balls_left',
#        'wickets_left', 'crr', 'rrr', 'result', 'BowlingTeam'],
#       dtype='object')

# %%
matches1.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
match_team_mapping = matches1.set_index('ID')[['Team1', 'Team2']]

def get_bowling_team(row):
    match_id = row['ID']
    batting_team = row['BattingTeam']

    if match_id in match_team_mapping.index:
        team1, team2 = match_team_mapping.loc[match_id]

        return team1 if batting_team == team2 else team2
    return None


ball_df['BowlingTeam'] = ball_df.apply(get_bowling_team, axis=1)
ball_df.head()
# Out:
#           ID       City       WinningTeam  total_run_x  innings  overs  \
# 127  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 128  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 129  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 130  1312199  Ahmedabad  Rajasthan Royals          161        2      0
# 131  1312199  Ahmedabad  Rajasthan Royals          161        2      0
#
#      ballnumber       batter          bowler non-striker  ...  \
# 127           1  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 128           2  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 129           3  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 130           4  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
# 131           5  YBK Jaiswal  Mohammed Siraj  JC Buttler  ...
#
#     fielders_involved       BattingTeam  current_score  runs_left  balls_left  \
# 127               NaN  Rajasthan Royals              0        162         125
# 128               NaN  Rajasthan Royals              0        162         124
# 129               NaN  Rajasthan Royals              6        156         123
# 130               NaN  Rajasthan Royals             10        152         122
# 131               NaN  Rajasthan Royals             10        152         121
#
#      wickets_left   crr       rrr result                  BowlingTeam
# 127             9  -0.0  7.776000      1  Royal Challengers Bangalore
# 128             8  -0.0  7.838710      1  Royal Challengers Bangalore
# 129             7 -12.0  7.609756      1  Royal Challengers Bangalore
# 130             6 -30.0  7.475410      1  Royal Challengers Bangalore
# 131             5 -60.0  7.537190      1  Royal Challengers Bangalore
#
# [5 rows x 28 columns]

# %% [markdown]
# # **Feature extraction**

# %%
final_df = ball_df[['BattingTeam','BowlingTeam','City','runs_left','balls_left','wickets_left','total_run_x','crr','rrr','result']]

# %% [markdown]
# Dropping Null Values

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df['balls_left']!=0]

# %%
final_df = final_df[final_df['crr'].replace([np.inf, -np.inf], np.nan).notna()]

# %%
final_df.describe()
# Out:
#           runs_left    balls_left  wickets_left   total_run_x           crr  \
# count  63994.000000  63994.000000  63994.000000  63994.000000  63994.000000
# mean      78.953496     68.222536    -49.673251    151.105401      8.735785
# std       46.771409     33.166717     34.278401     27.381689      7.458969
# min        1.000000      4.000000   -124.000000      2.000000   -126.000000
# 25%       40.000000     40.000000    -78.000000    135.000000      7.147059
# 50%       77.000000     69.000000    -49.000000    152.000000      8.480000
# 75%      115.000000     97.000000    -20.000000    169.000000     10.000000
# max      224.000000    125.000000      9.000000    223.000000    156.000000
#
#                 rrr        result
# count  63994.000000  63994.000000
# mean       6.667644      0.536519
# std        2.244511      0.498668
# min        0.050420      0.000000
# 25%        5.446457      0.000000
# 50%        6.923077      1.000000
# 75%        8.142857      1.000000
# max       16.235294      1.000000

# %%
final_df.head()
# Out:
#                   BattingTeam            BowlingTeam       City  runs_left  \
# 64187        Rajasthan Royals    Chennai Super Kings    Chennai        109
# 26925        Rajasthan Royals         Mumbai Indians  Abu Dhabi         24
# 115574       Delhi Daredevils  Kolkata Knight Riders    Kolkata        144
# 123799  Kolkata Knight Riders       Rajasthan Royals     Durban         94
# 91412        Delhi Daredevils         Mumbai Indians     Mumbai         47
#
#         balls_left  wickets_left  total_run_x        crr       rrr  result
# 64187           93           -23          145   8.222222  7.032258       0
# 26925           36           -81          136   8.071429  4.000000       0
# 115574         100           -17          167   7.200000  8.640000       0
# 123799         117             1          102  18.000000  4.820513       1
# 91412           40           -80          165   8.925000  7.050000       0

# %% [markdown]
# Shuffling Dataset to reduce bias

# %%
final_df=final_df.sample(final_df.shape[0])

# %% [markdown]
# # **Model Training**

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
categorical_features = ["BattingTeam", "BowlingTeam", "City"]

# %%
column_transformer = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), categorical_features)
    ],
    remainder="passthrough"
)

# %% [markdown]
# Pipelining using LogisticRegression

# %%
pipe = Pipeline(steps=[
    ('column_transformer', column_transformer),
    ('model', LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['BattingTeam', 'BowlingTeam',
#                                                    'City'])])),
#                 ('model', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6806781779826548

# %% [markdown]
# ### **This model give the probability of winning of the 2 teams at a certain point of match in the second innings**

# %%
pipe.predict_proba(X_test)[10]
# Out:
# array([0.41510236, 0.58489764])

# %% [markdown]
# Pipelining using RandomForestClassifier

# %%
pipe = Pipeline(steps=[
    ('column_transformer', column_transformer),
    ('model', RandomForestClassifier())
])

# %%
pipe.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['BattingTeam', 'BowlingTeam',
#                                                    'City'])])),
#                 ('model', RandomForestClassifier())])

# %%
y_pred = pipe.predict(X_test)

# %% [markdown]
# ### **This model predicts will the batting team will win or lose the match**

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.998281115712165
